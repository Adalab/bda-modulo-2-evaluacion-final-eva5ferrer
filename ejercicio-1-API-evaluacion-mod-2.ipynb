# %% [markdown]
# # Ejercicio 1. Creación de una base de datos de pelícuals extraídas de una API

# %% [markdown]
# En este ejercicio vamos a poner en práctica lo que hemos aprendido sobre la extracción de contenido de
# APIs y la creación de una base de datos con sus tablas. Siguiendo las fases propuestas, conseguiremos
# extraer datos de películas, almacenarlos en un DataFrame y finalmente crear una base de datos con la
# estructura adecuada.

# %% [markdown]
# ## Fase 1: Extracción de datos de películas

# %% [markdown]
# Nuestro primer objetivo es extraer los datos de películas de la API. En Adalab nos hemos creado un API
# muy sencilla que contiene la siguiente información:
#
# Datos a extraer:
# - Título
# - Año de lanzamiento
# - Duración (en minutos)
# - Género
# - Contenido para adultos (sí o no)
#
# El objetivo es extraer 100 películas de esta API utilizando el siguiente endpoint:
# https://beta.adalab.es/resources/apis/pelis/pelis.json

# %%
# Importamos primero las librerías requests y pandas:
import requests
import pandas as pd

# %%
url = "https://beta.adalab.es/resources/apis/pelis/pelis.json"

# %%
llamada = requests.get(url) # Relizamos la solicitud get al link proporcionado.
if llamada.status_code == 200:
    datos = llamada.json()
    print(datos)
else:
    print (f"Error --> {llamada.status_code}")
# Out:
# [{'id': 1, 'titulo': 'The Godfather', 'año': 1972, 'duracion': 175, 'genero': 'Crimen', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 2, 'titulo': 'The Godfather Part II', 'año': 1974, 'duracion': 202, 'genero': 'Crimen', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 3, 'titulo': 'Pulp Fiction', 'año': 1994, 'duracion': 154, 'genero': 'Crimen', 'adultos': True, 'subtitulos': ['es', 'en']}, {'id': 4, 'titulo': 'Forrest Gump', 'año': 1994, 'duracion': 142, 'genero': 'Drama', 'adultos': False, 'subtitulos': ['es', 'en', 'fr']}, {'id': 5, 'titulo': 'The Dark Knight', 'año': 2008, 'duracion': 152, 'genero': 'Acción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 6, 'titulo': 'Fight Club', 'año': 1999, 'duracion': 139, 'genero': 'Drama', 'adultos': True, 'subtitulos': ['es', 'en']}, {'id': 7, 'titulo': 'Inception', 'año': 2010, 'duracion': 148, 'genero': 'Ciencia ficción', 'adultos': False, 'subtitulos': ['es', 'en', 'de']}, {'id': 8, 'titulo': 'The Matrix', 'año': 1999, 'duracion': 136, 'genero': 'Ciencia ficción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 9, 'titulo': 'The Shawshank Redemption', 'año': 1994, 'duracion': 142, 'genero': 'Drama', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 10, 'titulo': 'Interstellar', 'año': 2014, 'duracion': 169, 'genero': 'Ciencia ficción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 11, 'titulo': 'Gladiator', 'año': 2000, 'duracion': 155, 'genero': 'Acción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 12, 'titulo': 'Titanic', 'año': 1997, 'duracion': 195, 'genero': 'Romance', 'adultos': False, 'subtitulos': ['es', 'en', 'fr']}, {'id': 13, 'titulo': 'Avatar', 'año': 2009, 'duracion': 162, 'genero': 'Ciencia ficción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 14, 'titulo': 'Saving Private Ryan', 'año': 1998, 'duracion': 169, 'genero': 'Bélico', 'adultos': True, 'subtitulos': ['es', 'en']}, {'id': 15, 'titulo': 'The Silence of the Lambs', 'año': 1991, 'duracion': 118, 'genero': 'Thriller', 'adultos': True, 'subtitulos': ['es', 'en']}, {'id': 16, 'titulo': 'Se7en', 'año': 1995, 'duracion': 127, 'genero': 'Thriller', 'adultos': True, 'subtitulos': ['es', 'en']}, {'id': 17, 'titulo': 'Goodfellas', 'año': 1990, 'duracion': 146, 'genero': 'Crimen', 'adultos': True, 'subtitulos': ['es', 'en']}, {'id': 18, 'titulo': 'The Departed', 'año': 2006, 'duracion': 151, 'genero': 'Crimen', 'adultos': True, 'subtitulos': ['es', 'en']}, {'id': 19, 'titulo': 'Whiplash', 'año': 2014, 'duracion': 106, 'genero': 'Drama', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 20, 'titulo': 'La La Land', 'año': 2016, 'duracion': 128, 'genero': 'Musical', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 21, 'titulo': 'The Lord of the Rings: The Fellowship of the Ring', 'año': 2001, 'duracion': 178, 'genero': 'Fantasía', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 22, 'titulo': 'The Lord of the Rings: The Two Towers', 'año': 2002, 'duracion': 179, 'genero': 'Fantasía', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 23, 'titulo': 'The Lord of the Rings: The Return of the King', 'año': 2003, 'duracion': 201, 'genero': 'Fantasía', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 24, 'titulo': 'Star Wars: A New Hope', 'año': 1977, 'duracion': 121, 'genero': 'Ciencia ficción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 25, 'titulo': 'Star Wars: The Empire Strikes Back', 'año': 1980, 'duracion': 124, 'genero': 'Ciencia ficción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 26, 'titulo': 'Star Wars: Return of the Jedi', 'año': 1983, 'duracion': 131, 'genero': 'Ciencia ficción', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 27, 'titulo': 'Back to the Future', 'año': 1985, 'duracion': 116, 'genero': 'Aventura', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 28, 'titulo': 'Jurassic Park', 'año': 1993, 'duracion': 127, 'genero': 'Aventura', 'adultos': False, 'subtitulos': ['es', 'en']}, {'id': 29, ' ...

# %%
datos
# Out:
# [{'id': 1,
#   'titulo': 'The Godfather',
#   'año': 1972,
#   'duracion': 175,
#   'genero': 'Crimen',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 2,
#   'titulo': 'The Godfather Part II',
#   'año': 1974,
#   'duracion': 202,
#   'genero': 'Crimen',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 3,
#   'titulo': 'Pulp Fiction',
#   'año': 1994,
#   'duracion': 154,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 4,
#   'titulo': 'Forrest Gump',
#   'año': 1994,
#   'duracion': 142,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 5,
#   'titulo': 'The Dark Knight',
#   'año': 2008,
#   'duracion': 152,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 6,
#   'titulo': 'Fight Club',
#   'año': 1999,
#   'duracion': 139,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 7,
#   'titulo': 'Inception',
#   'año': 2010,
#   'duracion': 148,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'de']},
#  {'id': 8,
#   'titulo': 'The Matrix',
#   'año': 1999,
#   'duracion': 136,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 9,
#   'titulo': 'The Shawshank Redemption',
#   'año': 1994,
#   'duracion': 142,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 10,
#   'titulo': 'Interstellar',
#   'año': 2014,
#   'duracion': 169,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 11,
#   'titulo': 'Gladiator',
#   'año': 2000,
#   'duracion': 155,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 12,
#   'titulo': 'Titanic',
#   'año': 1997,
#   'duracion': 195,
#   'genero': 'Romance',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 13,
#   'titulo': 'Avatar',
#   'año': 2009,
#   'duracion': 162,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 14,
#   'titulo': 'Saving Private Ryan',
#   'año': 1998,
#   'duracion': 169,
#   'genero': 'Bélico',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 15,
#   'titulo': 'The Silence of the Lambs',
#   'año': 1991,
#   'duracion': 118,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 16,
#   'titulo': 'Se7en',
#   'año': 1995,
#   'duracion': 127,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 17,
#   'titulo': 'Goodfellas',
#   'año': 1990,
#   'duracion': 146,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 18,
#   'titulo': 'The Departed',
#   'año': 2006,
#   'duracion': 151,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 19,
#   'titulo': 'Whiplash',
#   'año': 2014,
#   'duracion': 106,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 20,
#   'titulo': 'La La Land',
#   'año': 2016,
#   'duracion': 128,
#   'genero': 'Musical',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 21,
#   'titulo': 'The Lord of the Rings: The Fellowship of the Ring',
#   'año': 2001,
#   'duracion': 178,
#   'genero': 'Fantasía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 22,
#   'titulo': 'The Lord of the Rings: The Two Towers',
#   'año': 2002,
#   'duracion': 179,
#   'genero': 'Fantasía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 23,
#   'titulo': 'The Lord of the Rings: The Return of the King',
#   'año': 2003,
#   'duracion': 201,
#   'genero': 'Fantasía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 24,
#   'titulo': 'Star Wars: A New Hope',
#   'año': 1977,
#   'duracion': 121,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 25,
#   'titulo': 'Star Wars: The Empire Strikes Back',
#   'año': 1980,
#   'duracion': 124,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 26,
#   'titulo': 'Star Wars: Return of the Jedi',
#   'año': 1983,
#   'duracion': 131,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 27,
#   'titulo': 'Back to the Future',
#   'año': 1985,
#   'duracion': 116,
#   'genero': 'Aventura',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 28,
#   'titulo': 'Jurassic Park',
#   'año': 1993,
#   'duracion': 127,
#   'genero': 'Aventura',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 29,
#   'titulo': 'The Lion King',
#   'año': 1994,
#   'duracion': 88,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 30,
#   'titulo': 'Toy Story',
#   'año': 1995,
#   'duracion': 81,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 31,
#   'titulo': 'Finding Nemo',
#   'año': 2003,
#   'duracion': 100,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 32,
#   'titulo': 'Shrek',
#   'año': 2001,
#   'duracion': 90,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 33,
#   'titulo': 'The Incredibles',
#   'año': 2004,
#   'duracion': 115,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 34,
#   'titulo': 'WALL·E',
#   'año': 2008,
#   'duracion': 98,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 35,
#   'titulo': 'Up',
#   'año': 2009,
#   'duracion': 96,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 36,
#   'titulo': 'Spirited Away',
#   'año': 2001,
#   'duracion': 125,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'jp']},
#  {'id': 37,
#   'titulo': 'Princess Mononoke',
#   'año': 1997,
#   'duracion': 134,
#   'genero': 'Animación',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'jp']},
#  {'id': 38,
#   'titulo': 'The Green Mile',
#   'año': 1999,
#   'duracion': 189,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 39,
#   'titulo': 'The Truman Show',
#   'año': 1998,
#   'duracion': 103,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 40,
#   'titulo': 'The Social Network',
#   'año': 2010,
#   'duracion': 120,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 41,
#   'titulo': 'Joker',
#   'año': 2019,
#   'duracion': 122,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 42,
#   'titulo': 'Black Panther',
#   'año': 2018,
#   'duracion': 134,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 43,
#   'titulo': 'Iron Man',
#   'año': 2008,
#   'duracion': 126,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 44,
#   'titulo': 'The Avengers',
#   'año': 2012,
#   'duracion': 143,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 45,
#   'titulo': 'Avengers: Endgame',
#   'año': 2019,
#   'duracion': 181,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 46,
#   'titulo': 'Dune',
#   'año': 2021,
#   'duracion': 155,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 47,
#   'titulo': 'Mad Max: Fury Road',
#   'año': 2015,
#   'duracion': 120,
#   'genero': 'Acción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 48,
#   'titulo': 'The Revenant',
#   'año': 2015,
#   'duracion': 156,
#   'genero': 'Aventura',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 49,
#   'titulo': 'Parasite',
#   'año': 2019,
#   'duracion': 132,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'ko']},
#  {'id': 50,
#   'titulo': 'Oldboy',
#   'año': 2003,
#   'duracion': 120,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'ko']},
#  {'id': 51,
#   'titulo': 'The Pianist',
#   'año': 2002,
#   'duracion': 150,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 52,
#   'titulo': 'The Wolf of Wall Street',
#   'año': 2013,
#   'duracion': 180,
#   'genero': 'Biografía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 53,
#   'titulo': 'Her',
#   'año': 2013,
#   'duracion': 126,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 54,
#   'titulo': 'Gravity',
#   'año': 2013,
#   'duracion': 91,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 55,
#   'titulo': 'The Shape of Water',
#   'año': 2017,
#   'duracion': 123,
#   'genero': 'Fantasía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 56,
#   'titulo': 'Get Out',
#   'año': 2017,
#   'duracion': 104,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 57,
#   'titulo': 'It',
#   'año': 2017,
#   'duracion': 135,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 58,
#   'titulo': 'The Conjuring',
#   'año': 2013,
#   'duracion': 112,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 59,
#   'titulo': 'A Quiet Place',
#   'año': 2018,
#   'duracion': 90,
#   'genero': 'Terror',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 60,
#   'titulo': 'The Exorcist',
#   'año': 1973,
#   'duracion': 122,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 61,
#   'titulo': 'The Shining',
#   'año': 1980,
#   'duracion': 144,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 62,
#   'titulo': 'Blade Runner',
#   'año': 1982,
#   'duracion': 117,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 63,
#   'titulo': 'Blade Runner 2049',
#   'año': 2017,
#   'duracion': 164,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 64,
#   'titulo': 'Alien',
#   'año': 1979,
#   'duracion': 117,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 65,
#   'titulo': 'Aliens',
#   'año': 1986,
#   'duracion': 137,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 66,
#   'titulo': 'The Terminator',
#   'año': 1984,
#   'duracion': 107,
#   'genero': 'Acción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 67,
#   'titulo': 'Terminator 2: Judgment Day',
#   'año': 1991,
#   'duracion': 137,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 68,
#   'titulo': 'Rocky',
#   'año': 1976,
#   'duracion': 120,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 69,
#   'titulo': 'Raging Bull',
#   'año': 1980,
#   'duracion': 129,
#   'genero': 'Biografía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 70,
#   'titulo': 'Taxi Driver',
#   'año': 1976,
#   'duracion': 113,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 71,
#   'titulo': 'Casablanca',
#   'año': 1942,
#   'duracion': 102,
#   'genero': 'Romance',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 72,
#   'titulo': 'Citizen Kane',
#   'año': 1941,
#   'duracion': 119,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 73,
#   'titulo': 'Psycho',
#   'año': 1960,
#   'duracion': 109,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 74,
#   'titulo': 'Vertigo',
#   'año': 1958,
#   'duracion': 128,
#   'genero': 'Suspense',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 75,
#   'titulo': 'Rear Window',
#   'año': 1954,
#   'duracion': 112,
#   'genero': 'Suspense',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 76,
#   'titulo': '12 Angry Men',
#   'año': 1957,
#   'duracion': 96,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 77,
#   'titulo': "Schindler's List",
#   'año': 1993,
#   'duracion': 195,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 78,
#   'titulo': 'American Beauty',
#   'año': 1999,
#   'duracion': 122,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 79,
#   'titulo': 'No Country for Old Men',
#   'año': 2007,
#   'duracion': 122,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 80,
#   'titulo': 'The Big Lebowski',
#   'año': 1998,
#   'duracion': 117,
#   'genero': 'Comedia',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 81,
#   'titulo': 'Amélie',
#   'año': 2001,
#   'duracion': 122,
#   'genero': 'Romance',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 82,
#   'titulo': 'The Intouchables',
#   'año': 2011,
#   'duracion': 112,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 83,
#   'titulo': 'City of God',
#   'año': 2002,
#   'duracion': 130,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'pt']},
#  {'id': 84,
#   'titulo': "Pan's Labyrinth",
#   'año': 2006,
#   'duracion': 118,
#   'genero': 'Fantasía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 85,
#   'titulo': 'Roma',
#   'año': 2018,
#   'duracion': 135,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 86,
#   'titulo': 'Slumdog Millionaire',
#   'año': 2008,
#   'duracion': 120,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 87,
#   'titulo': 'Million Dollar Baby',
#   'año': 2004,
#   'duracion': 132,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 88,
#   'titulo': "The King's Speech",
#   'año': 2010,
#   'duracion': 118,
#   'genero': 'Biografía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 89,
#   'titulo': 'Argo',
#   'año': 2012,
#   'duracion': 120,
#   'genero': 'Thriller',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 90,
#   'titulo': 'Moonlight',
#   'año': 2016,
#   'duracion': 111,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 91,
#   'titulo': 'Manchester by the Sea',
#   'año': 2016,
#   'duracion': 137,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 92,
#   'titulo': 'Birdman',
#   'año': 2014,
#   'duracion': 119,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 93,
#   'titulo': 'Django Unchained',
#   'año': 2012,
#   'duracion': 165,
#   'genero': 'Western',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 94,
#   'titulo': 'Inglourious Basterds',
#   'año': 2009,
#   'duracion': 153,
#   'genero': 'Bélico',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 95,
#   'titulo': 'The Hateful Eight',
#   'año': 2015,
#   'duracion': 168,
#   'genero': 'Western',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 96,
#   'titulo': 'La vita è bella',
#   'año': 1997,
#   'duracion': 116,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'it']},
#  {'id': 97,
#   'titulo': 'Requiem for a Dream',
#   'año': 2000,
#   'duracion': 102,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 98,
#   'titulo': 'Memento',
#   'año': 2000,
#   'duracion': 113,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 99,
#   'titulo': 'Eternal Sunshine of the Spotless Mind',
#   'año': 2004,
#   'duracion': 108,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 100,
#   'titulo': 'Donnie Darko',
#   'año': 2001,
#   'duracion': 113,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']}]

# %%
datos_insercion_peliculas = []

for pelicula in datos:
    datos_insercion_peliculas.append(tuple(pelicula.values()))
print(datos_insercion_peliculas)
# Out:
# [(1, 'The Godfather', 1972, 175, 'Crimen', False, ['es', 'en']), (2, 'The Godfather Part II', 1974, 202, 'Crimen', False, ['es', 'en']), (3, 'Pulp Fiction', 1994, 154, 'Crimen', True, ['es', 'en']), (4, 'Forrest Gump', 1994, 142, 'Drama', False, ['es', 'en', 'fr']), (5, 'The Dark Knight', 2008, 152, 'Acción', False, ['es', 'en']), (6, 'Fight Club', 1999, 139, 'Drama', True, ['es', 'en']), (7, 'Inception', 2010, 148, 'Ciencia ficción', False, ['es', 'en', 'de']), (8, 'The Matrix', 1999, 136, 'Ciencia ficción', False, ['es', 'en']), (9, 'The Shawshank Redemption', 1994, 142, 'Drama', False, ['es', 'en']), (10, 'Interstellar', 2014, 169, 'Ciencia ficción', False, ['es', 'en']), (11, 'Gladiator', 2000, 155, 'Acción', False, ['es', 'en']), (12, 'Titanic', 1997, 195, 'Romance', False, ['es', 'en', 'fr']), (13, 'Avatar', 2009, 162, 'Ciencia ficción', False, ['es', 'en']), (14, 'Saving Private Ryan', 1998, 169, 'Bélico', True, ['es', 'en']), (15, 'The Silence of the Lambs', 1991, 118, 'Thriller', True, ['es', 'en']), (16, 'Se7en', 1995, 127, 'Thriller', True, ['es', 'en']), (17, 'Goodfellas', 1990, 146, 'Crimen', True, ['es', 'en']), (18, 'The Departed', 2006, 151, 'Crimen', True, ['es', 'en']), (19, 'Whiplash', 2014, 106, 'Drama', False, ['es', 'en']), (20, 'La La Land', 2016, 128, 'Musical', False, ['es', 'en']), (21, 'The Lord of the Rings: The Fellowship of the Ring', 2001, 178, 'Fantasía', False, ['es', 'en']), (22, 'The Lord of the Rings: The Two Towers', 2002, 179, 'Fantasía', False, ['es', 'en']), (23, 'The Lord of the Rings: The Return of the King', 2003, 201, 'Fantasía', False, ['es', 'en']), (24, 'Star Wars: A New Hope', 1977, 121, 'Ciencia ficción', False, ['es', 'en']), (25, 'Star Wars: The Empire Strikes Back', 1980, 124, 'Ciencia ficción', False, ['es', 'en']), (26, 'Star Wars: Return of the Jedi', 1983, 131, 'Ciencia ficción', False, ['es', 'en']), (27, 'Back to the Future', 1985, 116, 'Aventura', False, ['es', 'en']), (28, 'Jurassic Park', 1993, 127, 'Aventura', False, ['es', 'en']), (29, 'The Lion King', 1994, 88, 'Animación', False, ['es', 'en']), (30, 'Toy Story', 1995, 81, 'Animación', False, ['es', 'en']), (31, 'Finding Nemo', 2003, 100, 'Animación', False, ['es', 'en']), (32, 'Shrek', 2001, 90, 'Animación', False, ['es', 'en']), (33, 'The Incredibles', 2004, 115, 'Animación', False, ['es', 'en']), (34, 'WALL·E', 2008, 98, 'Animación', False, ['es', 'en']), (35, 'Up', 2009, 96, 'Animación', False, ['es', 'en']), (36, 'Spirited Away', 2001, 125, 'Animación', False, ['es', 'en', 'jp']), (37, 'Princess Mononoke', 1997, 134, 'Animación', True, ['es', 'en', 'jp']), (38, 'The Green Mile', 1999, 189, 'Drama', True, ['es', 'en']), (39, 'The Truman Show', 1998, 103, 'Drama', False, ['es', 'en']), (40, 'The Social Network', 2010, 120, 'Drama', False, ['es', 'en']), (41, 'Joker', 2019, 122, 'Drama', True, ['es', 'en']), (42, 'Black Panther', 2018, 134, 'Acción', False, ['es', 'en']), (43, 'Iron Man', 2008, 126, 'Acción', False, ['es', 'en']), (44, 'The Avengers', 2012, 143, 'Acción', False, ['es', 'en']), (45, 'Avengers: Endgame', 2019, 181, 'Acción', False, ['es', 'en']), (46, 'Dune', 2021, 155, 'Ciencia ficción', False, ['es', 'en']), (47, 'Mad Max: Fury Road', 2015, 120, 'Acción', True, ['es', 'en']), (48, 'The Revenant', 2015, 156, 'Aventura', True, ['es', 'en']), (49, 'Parasite', 2019, 132, 'Thriller', True, ['es', 'en', 'ko']), (50, 'Oldboy', 2003, 120, 'Thriller', True, ['es', 'en', 'ko']), (51, 'The Pianist', 2002, 150, 'Drama', True, ['es', 'en']), (52, 'The Wolf of Wall Street', 2013, 180, 'Biografía', True, ['es', 'en']), (53, 'Her', 2013, 126, 'Drama', False, ['es', 'en']), (54, 'Gravity', 2013, 91, 'Ciencia ficción', False, ['es', 'en']), (55, 'The Shape of Water', 2017, 123, 'Fantasía', True, ['es', 'en']), (56, 'Get Out', 2017, 104, 'Terror', True, ['es', 'en']), (57, 'It', 2017, 135, 'Terror', True, ['es', 'en']), (58, 'The Conjuring', 2013, 112, 'Terror', True, ['es', 'en']), (59, 'A Quiet Place', 2018, 90, ...

# %%
datos_insercion_peliculas #claro, pero aqui todavia nos sale el id, y los subtitutlos, que no los queremos.
# Out:
# [(1, 'The Godfather', 1972, 175, 'Crimen', False, ['es', 'en']),
#  (2, 'The Godfather Part II', 1974, 202, 'Crimen', False, ['es', 'en']),
#  (3, 'Pulp Fiction', 1994, 154, 'Crimen', True, ['es', 'en']),
#  (4, 'Forrest Gump', 1994, 142, 'Drama', False, ['es', 'en', 'fr']),
#  (5, 'The Dark Knight', 2008, 152, 'Acción', False, ['es', 'en']),
#  (6, 'Fight Club', 1999, 139, 'Drama', True, ['es', 'en']),
#  (7, 'Inception', 2010, 148, 'Ciencia ficción', False, ['es', 'en', 'de']),
#  (8, 'The Matrix', 1999, 136, 'Ciencia ficción', False, ['es', 'en']),
#  (9, 'The Shawshank Redemption', 1994, 142, 'Drama', False, ['es', 'en']),
#  (10, 'Interstellar', 2014, 169, 'Ciencia ficción', False, ['es', 'en']),
#  (11, 'Gladiator', 2000, 155, 'Acción', False, ['es', 'en']),
#  (12, 'Titanic', 1997, 195, 'Romance', False, ['es', 'en', 'fr']),
#  (13, 'Avatar', 2009, 162, 'Ciencia ficción', False, ['es', 'en']),
#  (14, 'Saving Private Ryan', 1998, 169, 'Bélico', True, ['es', 'en']),
#  (15, 'The Silence of the Lambs', 1991, 118, 'Thriller', True, ['es', 'en']),
#  (16, 'Se7en', 1995, 127, 'Thriller', True, ['es', 'en']),
#  (17, 'Goodfellas', 1990, 146, 'Crimen', True, ['es', 'en']),
#  (18, 'The Departed', 2006, 151, 'Crimen', True, ['es', 'en']),
#  (19, 'Whiplash', 2014, 106, 'Drama', False, ['es', 'en']),
#  (20, 'La La Land', 2016, 128, 'Musical', False, ['es', 'en']),
#  (21,
#   'The Lord of the Rings: The Fellowship of the Ring',
#   2001,
#   178,
#   'Fantasía',
#   False,
#   ['es', 'en']),
#  (22,
#   'The Lord of the Rings: The Two Towers',
#   2002,
#   179,
#   'Fantasía',
#   False,
#   ['es', 'en']),
#  (23,
#   'The Lord of the Rings: The Return of the King',
#   2003,
#   201,
#   'Fantasía',
#   False,
#   ['es', 'en']),
#  (24,
#   'Star Wars: A New Hope',
#   1977,
#   121,
#   'Ciencia ficción',
#   False,
#   ['es', 'en']),
#  (25,
#   'Star Wars: The Empire Strikes Back',
#   1980,
#   124,
#   'Ciencia ficción',
#   False,
#   ['es', 'en']),
#  (26,
#   'Star Wars: Return of the Jedi',
#   1983,
#   131,
#   'Ciencia ficción',
#   False,
#   ['es', 'en']),
#  (27, 'Back to the Future', 1985, 116, 'Aventura', False, ['es', 'en']),
#  (28, 'Jurassic Park', 1993, 127, 'Aventura', False, ['es', 'en']),
#  (29, 'The Lion King', 1994, 88, 'Animación', False, ['es', 'en']),
#  (30, 'Toy Story', 1995, 81, 'Animación', False, ['es', 'en']),
#  (31, 'Finding Nemo', 2003, 100, 'Animación', False, ['es', 'en']),
#  (32, 'Shrek', 2001, 90, 'Animación', False, ['es', 'en']),
#  (33, 'The Incredibles', 2004, 115, 'Animación', False, ['es', 'en']),
#  (34, 'WALL·E', 2008, 98, 'Animación', False, ['es', 'en']),
#  (35, 'Up', 2009, 96, 'Animación', False, ['es', 'en']),
#  (36, 'Spirited Away', 2001, 125, 'Animación', False, ['es', 'en', 'jp']),
#  (37, 'Princess Mononoke', 1997, 134, 'Animación', True, ['es', 'en', 'jp']),
#  (38, 'The Green Mile', 1999, 189, 'Drama', True, ['es', 'en']),
#  (39, 'The Truman Show', 1998, 103, 'Drama', False, ['es', 'en']),
#  (40, 'The Social Network', 2010, 120, 'Drama', False, ['es', 'en']),
#  (41, 'Joker', 2019, 122, 'Drama', True, ['es', 'en']),
#  (42, 'Black Panther', 2018, 134, 'Acción', False, ['es', 'en']),
#  (43, 'Iron Man', 2008, 126, 'Acción', False, ['es', 'en']),
#  (44, 'The Avengers', 2012, 143, 'Acción', False, ['es', 'en']),
#  (45, 'Avengers: Endgame', 2019, 181, 'Acción', False, ['es', 'en']),
#  (46, 'Dune', 2021, 155, 'Ciencia ficción', False, ['es', 'en']),
#  (47, 'Mad Max: Fury Road', 2015, 120, 'Acción', True, ['es', 'en']),
#  (48, 'The Revenant', 2015, 156, 'Aventura', True, ['es', 'en']),
#  (49, 'Parasite', 2019, 132, 'Thriller', True, ['es', 'en', 'ko']),
#  (50, 'Oldboy', 2003, 120, 'Thriller', True, ['es', 'en', 'ko']),
#  (51, 'The Pianist', 2002, 150, 'Drama', True, ['es', 'en']),
#  (52, 'The Wolf of Wall Street', 2013, 180, 'Biografía', True, ['es', 'en']),
#  (53, 'Her', 2013, 126, 'Drama', False, ['es', 'en']),
#  (54, 'Gravity', 2013, 91, 'Ciencia ficción', False, ['es', 'en']),
#  (55, 'The Shape of Water', 2017, 123, 'Fantasía', True, ['es', 'en']),
#  (56, 'Get Out', 2017, 104, 'Terror', True, ['es', 'en']),
#  (57, 'It', 2017, 135, 'Terror', True, ['es', 'en']),
#  (58, 'The Conjuring', 2013, 112, 'Terror', True, ['es', 'en']),
#  (59, 'A Quiet Place', 2018, 90, 'Terror', False, ['es', 'en']),
#  (60, 'The Exorcist', 1973, 122, 'Terror', True, ['es', 'en']),
#  (61, 'The Shining', 1980, 144, 'Terror', True, ['es', 'en']),
#  (62, 'Blade Runner', 1982, 117, 'Ciencia ficción', True, ['es', 'en']),
#  (63, 'Blade Runner 2049', 2017, 164, 'Ciencia ficción', True, ['es', 'en']),
#  (64, 'Alien', 1979, 117, 'Ciencia ficción', True, ['es', 'en']),
#  (65, 'Aliens', 1986, 137, 'Ciencia ficción', True, ['es', 'en']),
#  (66, 'The Terminator', 1984, 107, 'Acción', True, ['es', 'en']),
#  (67, 'Terminator 2: Judgment Day', 1991, 137, 'Acción', False, ['es', 'en']),
#  (68, 'Rocky', 1976, 120, 'Drama', False, ['es', 'en']),
#  (69, 'Raging Bull', 1980, 129, 'Biografía', True, ['es', 'en']),
#  (70, 'Taxi Driver', 1976, 113, 'Drama', True, ['es', 'en']),
#  (71, 'Casablanca', 1942, 102, 'Romance', False, ['es', 'en']),
#  (72, 'Citizen Kane', 1941, 119, 'Drama', False, ['es', 'en']),
#  (73, 'Psycho', 1960, 109, 'Terror', True, ['es', 'en']),
#  (74, 'Vertigo', 1958, 128, 'Suspense', False, ['es', 'en']),
#  (75, 'Rear Window', 1954, 112, 'Suspense', False, ['es', 'en']),
#  (76, '12 Angry Men', 1957, 96, 'Drama', False, ['es', 'en']),
#  (77, "Schindler's List", 1993, 195, 'Drama', True, ['es', 'en']),
#  (78, 'American Beauty', 1999, 122, 'Drama', True, ['es', 'en']),
#  (79, 'No Country for Old Men', 2007, 122, 'Crimen', True, ['es', 'en']),
#  (80, 'The Big Lebowski', 1998, 117, 'Comedia', True, ['es', 'en']),
#  (81, 'Amélie', 2001, 122, 'Romance', False, ['es', 'en', 'fr']),
#  (82, 'The Intouchables', 2011, 112, 'Drama', False, ['es', 'en', 'fr']),
#  (83, 'City of God', 2002, 130, 'Crimen', True, ['es', 'en', 'pt']),
#  (84, "Pan's Labyrinth", 2006, 118, 'Fantasía', True, ['es', 'en']),
#  (85, 'Roma', 2018, 135, 'Drama', True, ['es', 'en']),
#  (86, 'Slumdog Millionaire', 2008, 120, 'Drama', False, ['es', 'en']),
#  (87, 'Million Dollar Baby', 2004, 132, 'Drama', True, ['es', 'en']),
#  (88, "The King's Speech", 2010, 118, 'Biografía', False, ['es', 'en']),
#  (89, 'Argo', 2012, 120, 'Thriller', False, ['es', 'en']),
#  (90, 'Moonlight', 2016, 111, 'Drama', True, ['es', 'en']),
#  (91, 'Manchester by the Sea', 2016, 137, 'Drama', True, ['es', 'en']),
#  (92, 'Birdman', 2014, 119, 'Drama', True, ['es', 'en']),
#  (93, 'Django Unchained', 2012, 165, 'Western', True, ['es', 'en']),
#  (94, 'Inglourious Basterds', 2009, 153, 'Bélico', True, ['es', 'en']),
#  (95, 'The Hateful Eight', 2015, 168, 'Western', True, ['es', 'en']),
#  (96, 'La vita è bella', 1997, 116, 'Drama', False, ['es', 'en', 'it']),
#  (97, 'Requiem for a Dream', 2000, 102, 'Drama', True, ['es', 'en']),
#  (98, 'Memento', 2000, 113, 'Thriller', True, ['es', 'en']),
#  (99,
#   'Eternal Sunshine of the Spotless Mind',
#   2004,
#   108,
#   'Drama',
#   False,
#   ['es', 'en']),
#  (100, 'Donnie Darko', 2001, 113, 'Drama', True, ['es', 'en'])]

# %%
datos_insercion_sql = [] #aqui quito la informacion que no quiero (como el id o los subtitulos), y lo guardo en una tupla

for pelicula in datos:
    fila = (pelicula['titulo'],
            pelicula['año'],
            pelicula['duracion'],
            pelicula['genero'],
            pelicula['adultos'])

    datos_insercion_sql.append(fila)
datos_insercion_sql
# Out:
# [('The Godfather', 1972, 175, 'Crimen', False),
#  ('The Godfather Part II', 1974, 202, 'Crimen', False),
#  ('Pulp Fiction', 1994, 154, 'Crimen', True),
#  ('Forrest Gump', 1994, 142, 'Drama', False),
#  ('The Dark Knight', 2008, 152, 'Acción', False),
#  ('Fight Club', 1999, 139, 'Drama', True),
#  ('Inception', 2010, 148, 'Ciencia ficción', False),
#  ('The Matrix', 1999, 136, 'Ciencia ficción', False),
#  ('The Shawshank Redemption', 1994, 142, 'Drama', False),
#  ('Interstellar', 2014, 169, 'Ciencia ficción', False),
#  ('Gladiator', 2000, 155, 'Acción', False),
#  ('Titanic', 1997, 195, 'Romance', False),
#  ('Avatar', 2009, 162, 'Ciencia ficción', False),
#  ('Saving Private Ryan', 1998, 169, 'Bélico', True),
#  ('The Silence of the Lambs', 1991, 118, 'Thriller', True),
#  ('Se7en', 1995, 127, 'Thriller', True),
#  ('Goodfellas', 1990, 146, 'Crimen', True),
#  ('The Departed', 2006, 151, 'Crimen', True),
#  ('Whiplash', 2014, 106, 'Drama', False),
#  ('La La Land', 2016, 128, 'Musical', False),
#  ('The Lord of the Rings: The Fellowship of the Ring',
#   2001,
#   178,
#   'Fantasía',
#   False),
#  ('The Lord of the Rings: The Two Towers', 2002, 179, 'Fantasía', False),
#  ('The Lord of the Rings: The Return of the King',
#   2003,
#   201,
#   'Fantasía',
#   False),
#  ('Star Wars: A New Hope', 1977, 121, 'Ciencia ficción', False),
#  ('Star Wars: The Empire Strikes Back', 1980, 124, 'Ciencia ficción', False),
#  ('Star Wars: Return of the Jedi', 1983, 131, 'Ciencia ficción', False),
#  ('Back to the Future', 1985, 116, 'Aventura', False),
#  ('Jurassic Park', 1993, 127, 'Aventura', False),
#  ('The Lion King', 1994, 88, 'Animación', False),
#  ('Toy Story', 1995, 81, 'Animación', False),
#  ('Finding Nemo', 2003, 100, 'Animación', False),
#  ('Shrek', 2001, 90, 'Animación', False),
#  ('The Incredibles', 2004, 115, 'Animación', False),
#  ('WALL·E', 2008, 98, 'Animación', False),
#  ('Up', 2009, 96, 'Animación', False),
#  ('Spirited Away', 2001, 125, 'Animación', False),
#  ('Princess Mononoke', 1997, 134, 'Animación', True),
#  ('The Green Mile', 1999, 189, 'Drama', True),
#  ('The Truman Show', 1998, 103, 'Drama', False),
#  ('The Social Network', 2010, 120, 'Drama', False),
#  ('Joker', 2019, 122, 'Drama', True),
#  ('Black Panther', 2018, 134, 'Acción', False),
#  ('Iron Man', 2008, 126, 'Acción', False),
#  ('The Avengers', 2012, 143, 'Acción', False),
#  ('Avengers: Endgame', 2019, 181, 'Acción', False),
#  ('Dune', 2021, 155, 'Ciencia ficción', False),
#  ('Mad Max: Fury Road', 2015, 120, 'Acción', True),
#  ('The Revenant', 2015, 156, 'Aventura', True),
#  ('Parasite', 2019, 132, 'Thriller', True),
#  ('Oldboy', 2003, 120, 'Thriller', True),
#  ('The Pianist', 2002, 150, 'Drama', True),
#  ('The Wolf of Wall Street', 2013, 180, 'Biografía', True),
#  ('Her', 2013, 126, 'Drama', False),
#  ('Gravity', 2013, 91, 'Ciencia ficción', False),
#  ('The Shape of Water', 2017, 123, 'Fantasía', True),
#  ('Get Out', 2017, 104, 'Terror', True),
#  ('It', 2017, 135, 'Terror', True),
#  ('The Conjuring', 2013, 112, 'Terror', True),
#  ('A Quiet Place', 2018, 90, 'Terror', False),
#  ('The Exorcist', 1973, 122, 'Terror', True),
#  ('The Shining', 1980, 144, 'Terror', True),
#  ('Blade Runner', 1982, 117, 'Ciencia ficción', True),
#  ('Blade Runner 2049', 2017, 164, 'Ciencia ficción', True),
#  ('Alien', 1979, 117, 'Ciencia ficción', True),
#  ('Aliens', 1986, 137, 'Ciencia ficción', True),
#  ('The Terminator', 1984, 107, 'Acción', True),
#  ('Terminator 2: Judgment Day', 1991, 137, 'Acción', False),
#  ('Rocky', 1976, 120, 'Drama', False),
#  ('Raging Bull', 1980, 129, 'Biografía', True),
#  ('Taxi Driver', 1976, 113, 'Drama', True),
#  ('Casablanca', 1942, 102, 'Romance', False),
#  ('Citizen Kane', 1941, 119, 'Drama', False),
#  ('Psycho', 1960, 109, 'Terror', True),
#  ('Vertigo', 1958, 128, 'Suspense', False),
#  ('Rear Window', 1954, 112, 'Suspense', False),
#  ('12 Angry Men', 1957, 96, 'Drama', False),
#  ("Schindler's List", 1993, 195, 'Drama', True),
#  ('American Beauty', 1999, 122, 'Drama', True),
#  ('No Country for Old Men', 2007, 122, 'Crimen', True),
#  ('The Big Lebowski', 1998, 117, 'Comedia', True),
#  ('Amélie', 2001, 122, 'Romance', False),
#  ('The Intouchables', 2011, 112, 'Drama', False),
#  ('City of God', 2002, 130, 'Crimen', True),
#  ("Pan's Labyrinth", 2006, 118, 'Fantasía', True),
#  ('Roma', 2018, 135, 'Drama', True),
#  ('Slumdog Millionaire', 2008, 120, 'Drama', False),
#  ('Million Dollar Baby', 2004, 132, 'Drama', True),
#  ("The King's Speech", 2010, 118, 'Biografía', False),
#  ('Argo', 2012, 120, 'Thriller', False),
#  ('Moonlight', 2016, 111, 'Drama', True),
#  ('Manchester by the Sea', 2016, 137, 'Drama', True),
#  ('Birdman', 2014, 119, 'Drama', True),
#  ('Django Unchained', 2012, 165, 'Western', True),
#  ('Inglourious Basterds', 2009, 153, 'Bélico', True),
#  ('The Hateful Eight', 2015, 168, 'Western', True),
#  ('La vita è bella', 1997, 116, 'Drama', False),
#  ('Requiem for a Dream', 2000, 102, 'Drama', True),
#  ('Memento', 2000, 113, 'Thriller', True),
#  ('Eternal Sunshine of the Spotless Mind', 2004, 108, 'Drama', False),
#  ('Donnie Darko', 2001, 113, 'Drama', True)]

# %%
# Creamos el data frame para ver los datos que insertaremos en SQL.
df_peliculas = pd.DataFrame(datos_insercion_sql, columns = ['Título', 'Año', 'Duración', 'Género', 'Adultos'] )
df_peliculas
# Out:
#                                    Título   Año  Duración    Género  Adultos
# 0                           The Godfather  1972       175    Crimen    False
# 1                   The Godfather Part II  1974       202    Crimen    False
# 2                            Pulp Fiction  1994       154    Crimen     True
# 3                            Forrest Gump  1994       142     Drama    False
# 4                         The Dark Knight  2008       152    Acción    False
# ..                                    ...   ...       ...       ...      ...
# 95                        La vita è bella  1997       116     Drama    False
# 96                    Requiem for a Dream  2000       102     Drama     True
# 97                                Memento  2000       113  Thriller     True
# 98  Eternal Sunshine of the Spotless Mind  2004       108     Drama    False
# 99                           Donnie Darko  2001       113     Drama     True
#
# [100 rows x 5 columns]

# %%
# Para ver qué géneros tenemos:
genero = []
for pelicula in datos:
    tipo_genero = pelicula['genero']
    if tipo_genero not in genero:
        genero.append(tipo_genero)
genero
# Out:
# ['Crimen',
#  'Drama',
#  'Acción',
#  'Ciencia ficción',
#  'Romance',
#  'Bélico',
#  'Thriller',
#  'Musical',
#  'Fantasía',
#  'Aventura',
#  'Animación',
#  'Biografía',
#  'Terror',
#  'Suspense',
#  'Comedia',
#  'Western']

# %% [markdown]
# ## Fase 2: Creación de la Base de Datos
#
# Creamos la base de datos usando Python.

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
# Hacemos la conexión con el servidor:
cnx = mysql.connector.connect(
    user='eva5f',
    password='1006',
    host='127.0.0.1',
    auth_plugin = 'mysql_native_password'
)
# Imprimimos el objeto de conexión para verificar
print(cnx)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x118276310>

# %%
mycursor = cnx.cursor() # Iniciamos el cursor

mycursor.execute("CREATE SCHEMA IF NOT EXISTS peliculas;") # creamos el esquema en SQL

# %%
mycursor.close()
cnx.close() # cerramos la conexión

# %% [markdown]
# ## Fase 3: Inserción de los Datos en la Base de Datos

# %%
# Creo las dos tablas en SQL en el esquema "peliculas" ya creado con Python. 

# He introducido los generos en la tabla generos para ver qué IDs le ha dado SQL. El resultado es: 
    #'1','Crimen'
    #'2','Drama'
    #'3','Acción'
    #'4','Ciencia ficción'
    #'5','Romance'
    #'6','Bélico'
    #'7','Thriller'
    #'8','Musical'
    #'9','Fantasía'
    #'10','Aventura'
    #'11','Animación'
    #'12','Biografía'
    #'13','Terror'
    #'14','Suspense'
    #'15','Comedia'
    #'16','Western'

# %%
# ASIGNO CADA GÉNERO AL ID_GENERO USANDO UN BUCLE FOR:
datos_insercion_sql_final = [] 

for pelicula in datos:
    nombre_genero = pelicula["genero"]
    if nombre_genero == "Crimen":
        id_genero = 1
    elif nombre_genero == "Drama":
        id_genero = 2
    elif nombre_genero == "Acción":
        id_genero = 3
    elif nombre_genero == "Ciencia ficción":
        id_genero = 4
    elif nombre_genero == "Romance":
        id_genero = 5 
    elif nombre_genero == "Bélico":
        id_genero = 6
    elif nombre_genero == "Thriller":
        id_genero = 7
    elif nombre_genero == "Musical":
        id_genero = 8 
    elif nombre_genero == "Fantasía":
        id_genero = 9
    elif nombre_genero == "Aventura":
        id_genero = 10
    elif nombre_genero == "Animación":
        id_genero = 11
    elif nombre_genero == "Biografía":
        id_genero = 12
    elif nombre_genero == "Terror":
        id_genero = 13
    elif nombre_genero == "Suspense":
        id_genero = 14
    elif nombre_genero == "Comedia":
        id_genero = 15
    elif nombre_genero == "Western":
        id_genero = 16

    fila = (pelicula['titulo'],
            pelicula['año'],
            pelicula['duracion'],
            pelicula['adultos'],
            id_genero)

    datos_insercion_sql_final.append(fila)
datos_insercion_sql_final #este resultado va a ser lo que voy a copiar y pegar en SQL para introducir los valores en la tabla "peliculas".
# Out:
# [('The Godfather', 1972, 175, False, 1),
#  ('The Godfather Part II', 1974, 202, False, 1),
#  ('Pulp Fiction', 1994, 154, True, 1),
#  ('Forrest Gump', 1994, 142, False, 2),
#  ('The Dark Knight', 2008, 152, False, 3),
#  ('Fight Club', 1999, 139, True, 2),
#  ('Inception', 2010, 148, False, 4),
#  ('The Matrix', 1999, 136, False, 4),
#  ('The Shawshank Redemption', 1994, 142, False, 2),
#  ('Interstellar', 2014, 169, False, 4),
#  ('Gladiator', 2000, 155, False, 3),
#  ('Titanic', 1997, 195, False, 5),
#  ('Avatar', 2009, 162, False, 4),
#  ('Saving Private Ryan', 1998, 169, True, 6),
#  ('The Silence of the Lambs', 1991, 118, True, 7),
#  ('Se7en', 1995, 127, True, 7),
#  ('Goodfellas', 1990, 146, True, 1),
#  ('The Departed', 2006, 151, True, 1),
#  ('Whiplash', 2014, 106, False, 2),
#  ('La La Land', 2016, 128, False, 8),
#  ('The Lord of the Rings: The Fellowship of the Ring', 2001, 178, False, 9),
#  ('The Lord of the Rings: The Two Towers', 2002, 179, False, 9),
#  ('The Lord of the Rings: The Return of the King', 2003, 201, False, 9),
#  ('Star Wars: A New Hope', 1977, 121, False, 4),
#  ('Star Wars: The Empire Strikes Back', 1980, 124, False, 4),
#  ('Star Wars: Return of the Jedi', 1983, 131, False, 4),
#  ('Back to the Future', 1985, 116, False, 10),
#  ('Jurassic Park', 1993, 127, False, 10),
#  ('The Lion King', 1994, 88, False, 11),
#  ('Toy Story', 1995, 81, False, 11),
#  ('Finding Nemo', 2003, 100, False, 11),
#  ('Shrek', 2001, 90, False, 11),
#  ('The Incredibles', 2004, 115, False, 11),
#  ('WALL·E', 2008, 98, False, 11),
#  ('Up', 2009, 96, False, 11),
#  ('Spirited Away', 2001, 125, False, 11),
#  ('Princess Mononoke', 1997, 134, True, 11),
#  ('The Green Mile', 1999, 189, True, 2),
#  ('The Truman Show', 1998, 103, False, 2),
#  ('The Social Network', 2010, 120, False, 2),
#  ('Joker', 2019, 122, True, 2),
#  ('Black Panther', 2018, 134, False, 3),
#  ('Iron Man', 2008, 126, False, 3),
#  ('The Avengers', 2012, 143, False, 3),
#  ('Avengers: Endgame', 2019, 181, False, 3),
#  ('Dune', 2021, 155, False, 4),
#  ('Mad Max: Fury Road', 2015, 120, True, 3),
#  ('The Revenant', 2015, 156, True, 10),
#  ('Parasite', 2019, 132, True, 7),
#  ('Oldboy', 2003, 120, True, 7),
#  ('The Pianist', 2002, 150, True, 2),
#  ('The Wolf of Wall Street', 2013, 180, True, 12),
#  ('Her', 2013, 126, False, 2),
#  ('Gravity', 2013, 91, False, 4),
#  ('The Shape of Water', 2017, 123, True, 9),
#  ('Get Out', 2017, 104, True, 13),
#  ('It', 2017, 135, True, 13),
#  ('The Conjuring', 2013, 112, True, 13),
#  ('A Quiet Place', 2018, 90, False, 13),
#  ('The Exorcist', 1973, 122, True, 13),
#  ('The Shining', 1980, 144, True, 13),
#  ('Blade Runner', 1982, 117, True, 4),
#  ('Blade Runner 2049', 2017, 164, True, 4),
#  ('Alien', 1979, 117, True, 4),
#  ('Aliens', 1986, 137, True, 4),
#  ('The Terminator', 1984, 107, True, 3),
#  ('Terminator 2: Judgment Day', 1991, 137, False, 3),
#  ('Rocky', 1976, 120, False, 2),
#  ('Raging Bull', 1980, 129, True, 12),
#  ('Taxi Driver', 1976, 113, True, 2),
#  ('Casablanca', 1942, 102, False, 5),
#  ('Citizen Kane', 1941, 119, False, 2),
#  ('Psycho', 1960, 109, True, 13),
#  ('Vertigo', 1958, 128, False, 14),
#  ('Rear Window', 1954, 112, False, 14),
#  ('12 Angry Men', 1957, 96, False, 2),
#  ("Schindler's List", 1993, 195, True, 2),
#  ('American Beauty', 1999, 122, True, 2),
#  ('No Country for Old Men', 2007, 122, True, 1),
#  ('The Big Lebowski', 1998, 117, True, 15),
#  ('Amélie', 2001, 122, False, 5),
#  ('The Intouchables', 2011, 112, False, 2),
#  ('City of God', 2002, 130, True, 1),
#  ("Pan's Labyrinth", 2006, 118, True, 9),
#  ('Roma', 2018, 135, True, 2),
#  ('Slumdog Millionaire', 2008, 120, False, 2),
#  ('Million Dollar Baby', 2004, 132, True, 2),
#  ("The King's Speech", 2010, 118, False, 12),
#  ('Argo', 2012, 120, False, 7),
#  ('Moonlight', 2016, 111, True, 2),
#  ('Manchester by the Sea', 2016, 137, True, 2),
#  ('Birdman', 2014, 119, True, 2),
#  ('Django Unchained', 2012, 165, True, 16),
#  ('Inglourious Basterds', 2009, 153, True, 6),
#  ('The Hateful Eight', 2015, 168, True, 16),
#  ('La vita è bella', 1997, 116, False, 2),
#  ('Requiem for a Dream', 2000, 102, True, 2),
#  ('Memento', 2000, 113, True, 7),
#  ('Eternal Sunshine of the Spotless Mind', 2004, 108, False, 2),
#  ('Donnie Darko', 2001, 113, True, 2)]
